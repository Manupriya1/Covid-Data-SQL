# %%
import numpy as np
import pandas as pd

# %%
data =  pd.read_csv("csvData.csv")

# %%
data.rename(columns = {"Code":"state"}, inplace = True)

# %%
data
# Out:
#                    State  Abbrev state
# 0                Alabama    Ala.    AL
# 1                 Alaska  Alaska    AK
# 2                Arizona   Ariz.    AZ
# 3               Arkansas    Ark.    AR
# 4             California  Calif.    CA
# 5               Colorado   Colo.    CO
# 6            Connecticut   Conn.    CT
# 7               Delaware    Del.    DE
# 8   District of Columbia    D.C.    DC
# 9                Florida    Fla.    FL
# 10               Georgia     Ga.    GA
# 11                Hawaii  Hawaii    HI
# 12                 Idaho   Idaho    ID
# 13              Illinois    Ill.    IL
# 14               Indiana    Ind.    IN
# 15                  Iowa    Iowa    IA
# 16                Kansas   Kans.    KS
# 17              Kentucky     Ky.    KY
# 18             Louisiana     La.    LA
# 19                 Maine   Maine    ME
# 20              Maryland     Md.    MD
# 21         Massachusetts   Mass.    MA
# 22              Michigan   Mich.    MI
# ...

# %%
 covid_19 = pd.read_csv("United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv")

# %%
covid_19
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0          09/01/2021    ND     118491    107475.0     11016.0       536
# 1          01/13/2021    IN     574488         NaN         NaN      3654
# 2          04/17/2020    VI         54         NaN         NaN         1
# 3          07/30/2020    ME       3910      3497.0       413.0        22
# 4          02/02/2021    MS     280182    176228.0    103954.0      1059
# ...               ...   ...        ...         ...         ...       ...
# 38395      10/26/2020    SC     172486    163752.0      8734.0      1307
# 38396      08/03/2021    KY     491662    366391.0    125271.0      2622
# 38397      07/19/2020    NJ     178541         NaN         NaN       -10
# 38398      02/10/2021   FSM          1         1.0         0.0         0
# 38399      07/06/2021    OR     209494    209494.0         0.0       117
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
final_covid_data = pd.merge(covid_19, data)

# %%
final_covid_data.rename(columns = {"state":"code"}, inplace = True)

# %%
final_covid_data.head(5)
# Out:
#   submission_date code  tot_cases  conf_cases  prob_cases  new_case  \
# 0      09/01/2021   ND     118491    107475.0     11016.0       536
# 1      02/24/2020   ND          0         NaN         NaN         0
# 2      11/03/2020   ND      48301     48301.0         0.0      1114
# 3      07/19/2020   ND       5126      5126.0         0.0       107
# 4      10/18/2021   ND     142407    122955.0     19452.0       923
#
#    pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0       66.0       1562         NaN         NaN          1         0.0
# 1        NaN          0         NaN         NaN          0         NaN
# 2        0.0        568         NaN         NaN         12         0.0
# 3        0.0         93         NaN         NaN          1         0.0
# 4      429.0       1690         NaN         NaN         10         0.0
#
#                created_at consent_cases consent_deaths         State Abbrev
# ...

# %%
final_covid_data.drop(columns = ["created_at"], inplace = True)

# %%
final_covid_data
# Out:
#       submission_date code  tot_cases  conf_cases  prob_cases  new_case  \
# 0          09/01/2021   ND     118491    107475.0     11016.0       536
# 1          02/24/2020   ND          0         NaN         NaN         0
# 2          11/03/2020   ND      48301     48301.0         0.0      1114
# 3          07/19/2020   ND       5126      5126.0         0.0       107
# 4          10/18/2021   ND     142407    122955.0     19452.0       923
# ...               ...  ...        ...         ...         ...       ...
# 32635      06/20/2020   TN      37909     37665.0       244.0      1116
# 32636      03/04/2021   TN     781247    654016.0    127231.0      1146
# 32637      12/15/2020   TN     498020    448937.0     49083.0     10919
# 32638      05/28/2020   TN      23251     23097.0       154.0       660
# 32639      06/14/2020   TN      32785     32575.0       210.0       407
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
final_covid_data.to_csv("final_covid_data.csv", index = False)

# %%
covid_data = final_covid_data.fillna(0)

# %%
covid_data.to_csv("covid_data.csv", index = False)

# %%
covid_data.dtypes
# Out:
# submission_date     object
# code                object
# tot_cases            int64
# conf_cases         float64
# prob_cases         float64
# new_case             int64
# pnew_case          float64
# tot_death            int64
# conf_death         float64
# prob_death         float64
# new_death            int64
# pnew_death         float64
# consent_cases       object
# consent_deaths      object
# State               object
# dtype: object

# %%
data_sample = covid_data.sample(n = 1500)

# %%
data_sample
# Out:
#       submission_date code  tot_cases  conf_cases  prob_cases  new_case  \
# 30281      01/18/2021   PA     779671    687773.0     91898.0      3988
# 4099       04/17/2020   NE       1166         0.0         0.0        98
# 19768      09/08/2020   RI      22307         0.0         0.0        27
# 19824      08/24/2020   RI      21225         0.0         0.0        54
# 22167      05/12/2021   AR     338043         0.0         0.0       224
# ...               ...  ...        ...         ...         ...       ...
# 7935       07/04/2021   CA    3880664   3726303.0    154361.0      2178
# 13946      01/26/2020   KY          0         0.0         0.0         0
# 7243       09/05/2021   MD     503034         0.0         0.0       403
# 31403      10/02/2021   NM     254402         0.0         0.0       587
# 8695       12/30/2020   DE      58221     55884.0      2337.0       883
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
covid_data_sample = data_sample.to_csv("data_sample.csv", index = False)
